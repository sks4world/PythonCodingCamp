# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd

df=pd.read_csv('salary_by_language.csv')
df.head(10)
# Out:
#                 Language Average Salary  YoY % Increase
# 0               1.Golang      $132,827              NaN
# 1                2. Perl      $110,678             -2.7
# 2               3. Shell      $109,518              4.0
# 3  4. Node.js JavaScript      $105,418              3.7
# 4           5. Java/J2EE      $105,164              2.6
# 5          6. TypeScript      $103,680              1.7
# 6              7. Python      $103,587              0.4
# 7                8. Ruby      $102,086             -1.2
# 8               9. Swift      $101,631              3.2
# 9                 10. C#      $101,566              1.8

# %%
type(df.Language)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
def print_col_types():
    cols=df.columns
    for col in cols:
        print('Column ' + col + ' is of data type '+ str(type(df[col])))
        str1=str(type(df[col]))
        str2=str1[7:]
        str3=str2[:-1]
        #print('Column ' + col + ' is of data type '+ str3 )
        
        
def main():
    print_col_types()
    print(type(df))
    
main()
# Out:
# Column Language is of data type <class 'pandas.core.series.Series'>
# Column Average Salary is of data type <class 'pandas.core.series.Series'>
# Column YoY % Increase is of data type <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df))
df.columns=['prog_lang', 'avg_sal', 'sal_inc_pc']
df['avg_sal']=df['avg_sal'].str.replace('$','').str.replace(',','')
df['sal_inc_pc'].fillna(0.0, inplace=True)
#df['sal_inc_pc']=df['sal_inc_pc'].fillna(method='ffill', inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(10)
# Out:
#                prog_lang  avg_sal  sal_inc_pc
# 0               1.Golang  132827          0.0
# 1                2. Perl  110678         -2.7
# 2               3. Shell  109518          4.0
# 3  4. Node.js JavaScript  105418          3.7
# 4           5. Java/J2EE  105164          2.6
# 5          6. TypeScript  103680          1.7
# 6              7. Python  103587          0.4
# 7                8. Ruby  102086         -1.2
# 8               9. Swift  101631          3.2
# 9                 10. C#  101566          1.8

# %%
df = df.astype({'avg_sal':'int', 'sal_inc_pc':'float'})
#df = df.astype({'avg_sal':'int', 'sal_inc_pc':'int'})

# %%
print_col_types()
# Out:
# Column prog_lang is of data type <class 'pandas.core.series.Series'>
# Column avg_sal is of data type <class 'pandas.core.series.Series'>
# Column sal_inc_pc is of data type <class 'pandas.core.series.Series'>

# %%
df.prog_lang=df.prog_lang.str.replace('\d+','').str.replace('.','')

# %%
df.head(10)
# Out:
#             prog_lang  avg_sal  sal_inc_pc
# 0              Golang   132827         0.0
# 1                Perl   110678        -2.7
# 2               Shell   109518         4.0
# 3   Nodejs JavaScript   105418         3.7
# 4            Java/JEE   105164         2.6
# 5          TypeScript   103680         1.7
# 6              Python   103587         0.4
# 7                Ruby   102086        -1.2
# 8               Swift   101631         3.2
# 9                  C#   101566         1.8

# %%
print(df.shape)
# Out:
# (10, 3)

# %%
print(df.describe())
# Out:
#              avg_sal  sal_inc_pc
# count      10.000000   10.000000
# mean   107615.500000    1.350000
# std      9393.615069    2.198105
# min    101566.000000   -2.700000
# 25%    102461.250000    0.100000
# 50%    104422.000000    1.750000
# 75%    108493.000000    3.050000
# max    132827.000000    4.000000

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (14,5)

plt.hist(df.avg_sal)
plt.show()

# %%
import numpy as np

height = df.avg_sal
bars = df.prog_lang
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height, 0.3)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.title('Salary by Programming language')

 
# Show graphic
plt.show()

# %%
height1 = df.sal_inc_pc
bars1 = df.prog_lang
y_pos1 = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos1, height1, 0.3)
 
# Create names on the x-axis
plt.xticks(y_pos1, bars1)
plt.grid(color='black', linestyle='-', linewidth=0.2)
plt.title('Percentage change YoY in Salary')

 
# Show graphic
plt.show()

# %%
df1 = pd.read_csv('salayByExperience.csv')

# %%
X=df1.iloc[:,:-1].values #get a copy of dataset exclude last column

# %%
y=df1.iloc[:,1].values #get array of dataset in column 1st

# %%
viz=plt
viz.scatter(X_test, y_test, color='red')
viz.title('Salary VS Experience')
viz.xlabel('Year of Experience')
viz.ylabel('Salary')
viz.show()

# %%
# Splitting the dataset into the Training set and Test set

#from sklearn.model_selection import train_test_split
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
# Visualizing the Training set results
viz_train = plt
viz_train.scatter(X_train, y_train, color='red')
viz_train.plot(X_train, regressor.predict(X_train), color='blue')
viz_train.title('Salary VS Experience (Training set)')
viz_train.xlabel('Year of Experience')
viz_train.ylabel('Salary')
viz_train.show()

# %%
# Visualizing the Test set results
viz_test = plt
viz_test.scatter(X_test, y_test, color='red')
viz_test.plot(X_train, regressor.predict(X_train), color='blue')
viz_test.title('Salary VS Experience (Test set)')
viz_test.xlabel('Year of Experience')
viz_test.ylabel('Salary')
viz_test.show()
# Out:
# [[ 6.9]
#  [ 7.9]
#  [ 7.3]
#  [ 2.1]
#  [ 4.9]
#  [ 3.5]
#  [ 9.7]
#  [ 7.5]
#  [ 5.7]
#  [ 3.3]
#  [ 6.7]
#  [ 7.7]
#  [ 7.1]
#  [ 9.9]
#  [ 1.7]]

# %%
# Predicting the result of 5 Years Experience
y_pred = regressor.predict(5)
print(y_pred)
# Out:
# [ 32245.18748865]
